# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hwc.csv')
df_habitable = df[df['P_HABITABLE'] == 2]
df_casihabitable = df[df['P_HABITABLE'] == 1]
df_nohabitable = df[df['P_HABITABLE'] == 0]

# %% [markdown]
# # Pregunta Guía
#
# ¿Qué combinación de masa, radio y densidad hace más probable que un planeta retenga atmósfera y
# agua líquida? El foco está en las propiedades físicas que determinan si un planeta puede mantener
# condiciones superficiales estables

# %%
df_habitable
# Out:
#              P_NAME      P_DETECTION  \
# 113       TOI-904 c          Transit
# 559        GJ 357 d  Radial Velocity
# 626       GJ 3293 d  Radial Velocity
# 655        GJ 180 c  Radial Velocity
# 664        GJ 433 d  Radial Velocity
# 932      LHS 1140 b          Transit
# 1204   Kepler-705 b          Transit
# 1210   Kepler-452 b          Transit
# 1460         K2-9 b          Transit
# 1511       GJ 367 d  Radial Velocity
# 1612  Kepler-1544 b          Transit
# 1614  Kepler-1410 b          Transit
# 1657  Kepler-1540 b          Transit
# 1683  Kepler-1606 b          Transit
# 1731  Kepler-1653 b          Transit
# 1750    HD 216520 c  Radial Velocity
# 1767   Kepler-296 f          Transit
# 2011   Kepler-283 c          Transit
# 2178        K2-18 b          Transit
# 2283    Wolf 1061 c  Radial Velocity
# 2296       GJ 682 b  Radial Velocity
# 2411    HIP 38594 b  Radial Velocity
# 2522  Kepler-1701 b          Transit
# 2601    Kepler-62 e          Transit
# ...

# %% [markdown]
# ## ¿Cómo se distribuyen los tipos planetarios en el espacio masa–radio?

# %%
plt.scatter(df_habitable['P_MASS'], df_habitable['P_RADIUS'], s= 6, color='green', label="Habitabilidad=2")
plt.scatter(df_casihabitable['P_MASS'], df_casihabitable['P_RADIUS'], s= 6, color='red', label="Habitabilidad=1")
plt.scatter(df_nohabitable['P_MASS'], df_nohabitable['P_RADIUS'], s= 6, alpha=0.01, color='grey',label="Habitabilidad=0")

plt.xlabel('Masa')
plt.ylabel('Radio')
plt.xlim(0,12)
plt.ylim(0,3.5)
plt.title('Masa - Radio')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## ¿Existe relación entre densidad media y velocidad de escape?

# %%
plt.scatter(df_habitable['P_DENSITY'], df_habitable['P_ESCAPE'], s=4, alpha=1, color="green")
plt.scatter(df["P_DENSITY"], df["P_ESCAPE"], s=4, alpha=0.05, color="grey")
plt.xlim(-1,2)
plt.ylim(-1,30)
plt.xlabel('Densidad')
plt.ylabel('Velocidad de Escape')
# Out:
# Text(0, 0.5, 'Velocidad de Escape')

# %% [markdown]
# ## ¿Qué combinación de masa y temperatura parece más favorable para retener atmósfera?

# %%
plt.scatter(df_habitable['P_MASS'], df_habitable['P_TEMP_EQUIL'], s=4, alpha=1, color="green")
plt.scatter(df["P_MASS"], df["P_TEMP_EQUIL"], s=4, alpha=0.05, color="grey")
plt.xlim(0,20)
plt.ylim(0,2000)
plt.xlabel('Masa')
plt.ylabel('Temperatura de equilibrio')
# Out:
# Text(0, 0.5, 'Temperatura de equilibrio')

# %% [markdown]
# ## Condición de habitabilidad de base a la gravedad, cercana a la tierra.

# %%
df_ideales = df_habitable[df['P_GRAVITY'] <= 1.06]
df_ideales
# Out:
# /tmp/ipykernel_5064/578696546.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_ideales = df_habitable[df['P_GRAVITY'] <= 1.06]
#            P_NAME      P_DETECTION    P_DISCOVERY_FACILITY  P_YEAR  \
# 1750  HD 216520 c  Radial Velocity  Multiple Observatories    2020
# 2411  HIP 38594 b  Radial Velocity  Multiple Observatories    2020
# 3564   GJ 229 A c  Radial Velocity     Multiple Facilities    2020
#
#         P_UPDATE   P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  P_MASS_LIMIT  \
# 1750  2020-12-10  9.44000          -1.63000           1.63000             0
# 2411  2020-09-08  8.10000          -1.70000           1.70000             0
# 3564  2023-06-14  8.58137          -0.63566           0.63566             0
#
#      P_MASS_ORIGIN  ...  S_ABIO_ZONE  S_TIDAL_LOCK  P_HABZONE_OPT  \
# 1750         Msini  ...     0.595468      0.451358              1
# 2411         Msini  ...     0.094070      0.391256              1
# ...

# %%
plt.scatter(df['P_MASS'], df['P_RADIUS'],s= 8, alpha= 0.1,color='grey')
plt.scatter(df_ideales['P_MASS'], df_ideales['P_RADIUS'],s= 8, alpha= 1,color='red', label="Candidatos")
plt.xlim(0,50)
plt.ylim(0,10)
plt.xlabel('Masa')
plt.ylabel('Radio')
plt.title('Masa - Radio')
plt.grid()
plt.legend()
plt.show()

# %%
plt.scatter(df_ideales['P_RADIUS'], df_ideales['P_MASS'],
            s= 10, marker='o', color = "green")
#plt.scatter(df_habitable_2['P_RADIUS'], df_habitable_2['P_MASS'], s= 1, marker='s', color = "blue")
#plt.scatter(df_habitable_0['P_RADIUS'], df_habitable_0['P_MASS'], s= 1, marker='d', color = "grey")

plt.title("Distribución radio-masa 3 planetas candidatos")
plt.xlabel("Radius [Earth Radius]")
plt.ylabel("Mass [Earth Masses]")
plt.xlim(1.5, 3.25)   # set the xlim to left, right
plt.ylim(2, 10)
plt.grid(linestyle='--', linewidth=0.5, alpha=0.5)
